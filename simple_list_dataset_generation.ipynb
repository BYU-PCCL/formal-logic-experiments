# %%
import numpy as np

# %%
OBJECTS = [
    "Apple",
    "Conditioner",
    "Airport",
    "Ambulance",
    "Aircraft",
    "Apartment",
    "Arrow",
    "Alligator",
    "Architect",
    "Ankle",
    "Armchair",
    "Aunt",
    "Ball",
    "Bean",
    "Balloon",
    "Bear",
    "Blouse",
    "Bed",
    "Bow",
    "Bread",
    "Black",
    "Board",
    "Bone",
    "Bill",
    "Boxer",
    "Belt",
    "Brain",
    "Buffalo",
    "Bird",
    "Baby",
    "Book",
    "Butter",
    "Bulb",
    "Buckle",
    "Bat",
    "Bank",
    "Bag",
    "Bra",
    "Boot",
    "Blazer",
    "Bikini",
    "Bookcase",
    "Bookstore",
    "Bus stop",
    "Brass",
    "Brother",
    "Boy",
    "Blender",
    "Bucket",
    "Bakery",
    "Bow",
    "Bridge",
    "Boat",
    "Car",
    "Cow",
    "Cap",
    "Cooker",
    "Cheese",
    "Credenza",
    "Carpet",
    "Crow",
    "Crest",
    "Chest",
    "Chair",
    "Candy",
    "Cabinet",
    "Cat",
    "Coffee",
    "Children",
    "Cookware",
    "Chaise longue",
    "Chicken",
    "Casino",
    "Cabin",
    "Castle",
    "Church",
    "Cafe",
    "Cinema",
    "Choker",
    "Cravat",
    "Cane",
    "Costume",
    "Cardigan",
    "Chocolate",
    "Crib",
    "Couch",
    "Cello",
    "Cashier",
    "Composer",
    "Cave",
    "Country",
    "Computer",
    "Canoe",
    "Clock",
    "Dog",
    "Deer",
    "Donkey",
    "Desk",
    "Desktop",
    "Dress",
    "Dolphin",
    "Doctor",
    "Dentist",
    "Drum",
    "Dresser",
    "Designer",
    "Detective",
    "Egg",
    "Elephant",
    "Earrings",
    "Ears",
    "Eye",
    "Finger",
    "Fox",
    "Frock",
    "Frog",
    "Fan",
    "Freezer",
    "Fish",
    "Film",
    "Foot",
    "Flag",
    "Factory",
    "Father",
    "Farm",
    "Forest",
    "Flower",
    "Fruit",
    "Fork",
    "Grapes",
    "Goat",
    "Gown",
    "Garlic",
    "Ginger",
    "Giraffe",
    "Gauva",
    "Grain",
    "Gas station",
    "Garage",
    "Glove",
    "Gift",
    "Galaxy",
    "Guitar",
    "Governor",
    "Guest",
    "Hamburger",
    "Hand",
    "Hair",
    "Heart",
    "House",
    "Horse",
    "Hen",
    "Horn",
    "Hat",
    "Hammer",
    "Hostel",
    "Hospital",
    "Hotel",
    "Herb",
    "Jacket",
    "Jersey",
    "Jewelry",
    "Jaw",
    "Jumper",
    "Judge",
    "Juicer",
    "Keyboard",
    "Kangaroo",
    "Koala",
    "Knife",
    "Lemon",
    "Lion",
    "Laptop",
    "Library",
    "Lamb",
    "Lip",
    "Lung",
    "Lighter",
    "Luggage",
    "Lamp",
    "Lawyer",
    "Mouse",
    "Monkey",
    "Mango",
    "Mirror",
    "Musician",
    "Man",
    "Model",
    "Mll",
    "Museum",
    "Market",
    "Microscope",
    "Newspaper",
    "Nose",
    "Notebook",
    "Neck",
    "Noodle",
    "Nurse",
    "Necklace",
    "Noise",
    "Ocean",
    "Ostrich",
    "Oil",
    "Orange",
    "Onion",
    "Oven",
    "Owl",
    "Paper",
    "Panda",
    "Pumpkin",
    "Pharmacist",
    "Potato",
    "Perfume",
    "Panther",
    "Pencil",
    "Pipe",
    "Pen",
    "Pharmacy",
    "Parrot",
    "Plane",
    "Pigeon",
    "Phone",
    "Peacock",
    "Pencil",
    "Pig",
    "Pyramid",
    "Purse",
    "Pancake",
    "Popcorn",
    "Piano",
    "Physician",
    "Photographer",
    "Professor",
    "Painter",
    "Park",
    "Plant",
    "Radio",
    "Razor",
    "Rib",
    "Rainbow",
    "Rabbit",
    "Refrigerator",
    "Restaurant",
    "Road",
    "Surgeon",
    "Scale",
    "Sink",
    "Shark",
    "Sandal",
    "Shoulder",
    "Spoon",
    "Soap",
    "Sheep",
    "Stomach",
    "Soup",
    "Shoe",
    "Sparrow",
    "Shirt",
    "Suitcase",
    "Stove",
    "Snowman",
    "Shower",
    "Swan",
    "Suit",
    "Sweater",
    "Skirt",
    "Sofa",
    "Sock",
    "Stadium",
    "Skyscraper",
    "School",
    "Sandwich",
    "Strawberry",
    "Spaghetti",
    "Shrimp",
    "Saxophone",
    "Singer",
    "Senator",
    "Street",
    "Supermarket",
    "Swimming pool",
    "Star",
    "Sun",
    "Spoon",
    "Ship",
    "Table",
    "Turkey",
    "Tie",
    "Toe",
    "Truck",
    "Train",
    "Taxi",
    "Tiger",
    "Tongue",
    "Television",
    "Teacher",
    "Turtle",
    "Tablet",
    "Train station",
    "Tail",
    "Theater",
    "Trench coat",
    "Tomato",
    "Tunnel",
    "Temple",
    "Town",
    "Toothbrush",
    "Tree",
    "Toy",
    "Tissue",
    "Telephone",
    "Umbrella",
    "Vest",
    "Voice",
    "Veterinarian",
    "Villa",
    "Violin",
    "Village",
    "Vehicle",
    "Vase",
    "Wallet",
    "Wolf",
    "Waist",
    "Wrist",
    "Watermelon",
    "Whale",
    "Wing",
    "Whisker",
    "Watch",
    "Woman",
    "Washing machine",
    "Wheelchair",
    "Waiter",
    "Wound",
    "Zebra",
    "Zoo",
]

# %%
def prepend_article(word):
    if not word:
        raise ValueError("Word cannot be empty")

    first_letter = word[0].lower()

    if first_letter in "aeiou":
        return "an " + word
    else:
        return "a " + word

# %%
def generate_training_example(greater_than, relationship, less_than):
    return f"{prepend_article(greater_than.lower())} {relationship} {prepend_article(less_than.lower())}".capitalize()

# %%
generate_training_example("Alphabet", "is more blivergent", "Wheelchair")

# %%
generator: np.random.Generator

# %%
from numpy.random import Generator, PCG64


def generate_training_examples(n, relationship):
    global generator
    # Randomly sample training examples without replacement
    training_objects = generator.choice(OBJECTS, n)
    # Shuffle the training examples
    generator.shuffle(training_objects)
    training_examples = []
    test_examples = {}
    for i in range(n - 1):
        greater_than, less_than = training_objects[i], training_objects[i + 1]
        training_examples.append(
            generate_training_example(greater_than, relationship, less_than)
        )
    # Generate all possible pairs for test examples
    for distance in range(1, n):
        test_examples[distance] = []
        for i in range(n - distance):
            greater_than, less_than = (
                training_objects[i],
                training_objects[i + distance],
            )
            # Check if the pair exists in training examples
            if not any(
                [
                    greater_than == ex[0] and less_than == ex[2]
                    for ex in training_examples
                ]
            ):
                test_examples[distance].append(
                    generate_training_example(greater_than, relationship, less_than)
                )
    return training_examples, test_examples

# %%
generator = np.random.default_rng(12345)
generate_training_examples(20, "is more blivergent than")
